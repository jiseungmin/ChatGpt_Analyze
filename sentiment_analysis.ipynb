# %%
import pandas as pd
df = pd.read_csv("./TweetData/오징어_게임_ko.csv")
df
# Out:
#                   author id                created_at place_id  \
# 0       1332502535052034048  2022-07-07T23:58:14.000Z
# 1       1047089830398550016  2022-07-07T23:57:39.000Z
# 2       1321692888984547328  2022-07-07T23:56:40.000Z
# 3       1360639060188909572  2022-07-07T23:55:05.000Z
# 4       1029925887100084224  2022-07-07T23:54:17.000Z
# ...                     ...                       ...      ...
# 153813  1405227645390888960  2021-09-17T00:11:37.000Z
# 153814           3599794093  2021-09-17T00:11:02.000Z
# 153815  1373572486076403724  2021-09-17T00:10:27.000Z
# 153816            369905615  2021-09-17T00:06:24.000Z
# 153817           3026881800  2021-09-17T00:06:02.000Z
#
#                          id lang  like_count  quote_count  reply_count  \
# 0       1545195516505440256   ko           0            0            0
# 1       1545195372192342016   ko           0            0            0
# 2       1545195122551169024   ko           0            0            0
# ...

# %%
df=df[-df["text"].str.contains("https|출장|account is temporarily unavailable because|헬스보이짐|잠원지수영장0시간|#출장걸|안마방|룸싸룽|야식애인|화성카센터|홍어삼합|대덕대학교이름|유흥업소|마다가스카르토아마시나|고창군낚시터|청도군알뜰매장|땅따먹기|영암군철물점|전북28살여자|엄브렐라|유흥|셀스타그램|합천|실내복증정|인형녀|ㅈㄱㅁㄴ|쉼터냥이들|워킹대디|봉화군아침스타그램|동작구사우나|고창군노래방|조건만남|FWB|상서구캠핑장|지민|sex|yu1love_|เปิดเทอมปุ๊บซีรีส์น่าดูยาวเลย|신송홀딩스")]
df["text"].str.contains("헬스보이짐")
# Out:
# 374       False
# 387       False
# 397       False
# 403       False
# 416       False
#           ...
# 153811    False
# 153812    False
# 153813    False
# 153814    False
# 153816    False
# Name: text, Length: 78127, dtype: bool

# %%
# 'text' 컬럼만 선택하여 새로운 데이터프레임을 생성합니다.
text_df = df[['text']]

# 선택한 컬럼을 'new_file_name.csv' 파일로 저장합니다.
text_df.to_csv('./text.csv', index=False,encoding='utf-8-sig')

# %%
for i in range(100):
  print(df["text"].iloc[i])
# Out:
# @myangtaku 이제 즐거운 오징어 게임
# @jisung_ball 오징어게임극찬할듯
# @p13_DnF 그런가요..? 아 근데 연애는 바라기라서 잘할자신 있는데 멀티가안되서 연애+게임조합도 잘 안맞는 타입;;
# (그리고 오징어똥자루)
# @yeomdayeon 제가선택한 자살방법은 해외에서 난리난 오징어게임 시즌2 예고편 중국이 경악한 우리나라 국가대표 쇼트트랙 일본이 열폭하는 k-드라마 종이의집 도쿄 실시간 외국인반응 시청하기
# 오징어게임 250번 참가자 이지랄
# 노승환 이새끼 오징어게임에 던져놔야ㅠ정신을 차리지
# @give_me___money 나 오징어 게임 안봐서 몰라
# @ZCh3m 오징어게임 주인공 모에화한것같이 생긋다
# @그치만 헤결이 흥행 못 하는 건 슬퍼
# 근데 헤결이 오징어게임처럼 유행하는 상상하니까 그건 그거대로 골때리긴 한다
# 대중성엔 대가가 따르는 거구나
# 이게오징어게임도아니고
# 빡빡머리1나명 죽인다는데 다들 동의햇다는게
# 20대 남배 그냥 지들끼리 드라마찍는데
# 오징어게임찍나봐
# 서바이벌 좆된다ㄹㅇ
# 몇명남았니 이제
# 두ㅍ손다 피면 힘들까봐 친히 한 손 안으로 만들어준다 얘네가ㅋㅋㅋㅋ
# 아니… 아니 오징어게임 설대생이 슬감빵 걔였어????!!! 와 나 전혀 몰랐어
# 저 이장 친구 오징어 게임 징검다리 아저씨 같은데?
# 집가서 오징어 뜯으면서 게임할거야
# ㄴ 희망사항
# @Xixi_fact 정말 웃겨 죽겠어요. 섬나라 대면적의 기억 전승자 수박이 어떻게 도처에 널려 있는 게 못 먹는 것 같나요? 방망이가 조금만 더 큰 힘을 내도 작지 않은 작은 김치가 이 메스꺼운 사람이 틈틈이 오징어 게임을 많이 하면 더 이상 빈둥거리며 중국 국가 지도자를 헐뜯지 마라 아직 그 자격이 부족하다
# @munashkam94 Abdulhamid Poytaxt. Va oxirgilaridan 오징어 게임  ko'pchilik kulgan nimasi yig'latdi buni? Deb
# Va 지금 우리 헉교는
# ...
